# %% [markdown]
# # Raw Data Discovery
# ## Car Colliosions Jefferson County 2019-2020

# %%
import pandas as pd
excel_file_jan = pd.read_excel('data/raw_data/jan_crashes_2019.xlsx')
crashes = pd.read_csv('data/raw_data/raw_merge/raw_data_main.csv')
cars = pd.read_csv('data/raw_data/raw_merge/raw_data_car.csv')

# %%
excel_file_jan
# Out:
#       IncidentID  AgencyORI                      AgencyName  \
# 0       24574869     568000    LOUISVILLE METRO POLICE DEPT
# 1       24652051     568000    LOUISVILLE METRO POLICE DEPT
# 2       24574840     568000    LOUISVILLE METRO POLICE DEPT
# 3       24574843     568000    LOUISVILLE METRO POLICE DEPT
# 4       24574829     568000    LOUISVILLE METRO POLICE DEPT
# ...          ...        ...                             ...
# 2452    24442338     568000    LOUISVILLE METRO POLICE DEPT
# 2453    24438964     560300  ST. MATTHEWS POLICE DEPARTMENT
# 2454    24442545     568000    LOUISVILLE METRO POLICE DEPT
# 2455    24442546     568000    LOUISVILLE METRO POLICE DEPT
# 2456    24450507     564500      PROSPECT POLICE DEPARTMENT
#
#      IncidentStatusDesc     County RdwyNumber Street   RoadwayName StreetSfx  \
# 0              Accepted  JEFFERSON    US0031E    NaN          MAIN        ST
# 1              Accepted  JEFFERSON     KY0155    NaN  TAYLORSVILLE        RD
# ...

# %%
crashes
# Out:
#        IncidentID AgencyORI                    AgencyName IncidentStatusDesc  \
# 0        24556990    568000  LOUISVILLE METRO POLICE DEPT           Accepted
# 1        24442324    568000  LOUISVILLE METRO POLICE DEPT           Accepted
# 2        24442311    568000  LOUISVILLE METRO POLICE DEPT           Accepted
# 3        24442346    568000  LOUISVILLE METRO POLICE DEPT           Accepted
# 4        24442344    568000  LOUISVILLE METRO POLICE DEPT           Accepted
# ...           ...       ...                           ...                ...
# 48000    27631000   0568000  LOUISVILLE METRO POLICE DEPT           Accepted
# 48001    27630974   0568000  LOUISVILLE METRO POLICE DEPT           Accepted
# 48002    27630984   0568000  LOUISVILLE METRO POLICE DEPT           Accepted
# 48003    27624749   0560400     SHIVELY POLICE DEPARTMENT           Accepted
# 48004    27620989   0561000     JEFFERSONTOWN POLICE DEPT           Accepted
#
# ...

# %%
cars
# Out:
#         IncidentID MakeDescription ModelDescription  CollisionTime  \
# 0         24442346       CHEVROLET            SONIC           20.0
# 1         24442338             NaN              NaN           12.0
# 2         24442536            FORD           TAURUS           14.0
# 3         24440390         HYUNDAI          ELANTRA           18.0
# 4         24442531          NISSAN            QUEST            9.0
# ...            ...             ...              ...            ...
# 109059    27630965        CADILLAC              CTS           12.0
# 109060    27630966       CHEVROLET           IMPALA           11.0
# 109061    27619140         PONTIAC               G6           10.0
# 109062    27636533         HYUNDAI           ACCENT           17.0
# 109063    27636542             NaN              NaN            9.0
#
#        CollisionDate
# 0         2019-01-01
# 1         2019-01-01
# 2         2019-01-01
# 3         2019-01-01
# 4         2019-01-01
# ...              ...
# ...
