# %% [markdown]
# Data Analysis - Car Colliosions Jefferson Count 2019-2020

# %%
import pandas as pd
import numpy as np
crashes = pd.read_csv('data/clean_data/clean_data.csv')

# %%
crashes['RoadwayName'].sort_values().unique().tolist()
# Out:
# ['10TH',
#  '11TH',
#  '12TH',
#  '12TH ST CONN',
#  '13TH',
#  '15TH',
#  '16TH',
#  '17TH',
#  '18TH',
#  '19TH',
#  '1ST',
#  '20TH',
#  '21ST',
#  '22ND',
#  '23RD',
#  '24TH',
#  '25TH',
#  '264',
#  '264W OFF RAMP TO TAYLOR BLVD',
#  '26TH',
#  '27TH',
#  '28TH',
#  '29TH',
#  '2ND',
#  '30TH',
#  '31ST',
#  '32ND',
#  '33RD',
#  '34TH',
#  '35TH',
#  '36TH',
#  '37TH',
#  '38TH',
#  '39TH',
#  '3RD',
#  '3RD ST',
#  '40TH',
#  '41ST',
#  '42ND',
#  '43RD',
#  '44TH',
#  '45TH',
#  '46TH',
#  '4TH',
#  '5TH',
#  '6TH',
#  '7TH',
#  '7TH ST',
#  '7TH STREET',
#  '8TH',
#  '9TH',
#  'AARON CREEK',
#  'ABBEYWOOD',
#  'ABERNATHY',
#  'ABIGAIL',
#  'ABRAHAM FLEXNER',
#  'ACADEMY RIDGE',
#  'ACAPOLCA',
#  'ACCASIA',
#  'ACCOMACK',
#  'ACTION',
#  'ADAMS',
#  'ADAMS RUN',
#  'ADDISON',
#  'ADELE',
#  'ADMINISTRATION',
#  'ADVENTURE',
#  'AFTERGLOW',
#  'AHLAND',
#  'AIKEN',
#  'AIKEN ROAD',
#  'AINTREE',
#  'AIR COMMERCE',
#  'AIRFREIGHT',
#  'ALANMEDE',
#  'ALBION',
#  'ALDER',
# ...
